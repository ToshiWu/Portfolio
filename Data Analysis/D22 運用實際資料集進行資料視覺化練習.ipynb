# %% [markdown]
# 目標: 使用 Seaborn 自帶的dataset, 利用 PANDAS 處理來繪製資料集的可視化圖表
#
# 重點: 不同型態的類別要套用的對應圖像是不一樣的
#
# (1) 做條形圖
#
# (2) 利用 facet grid 繪圖並分析
#
# 題目 : 取得另一個 dataset: titanic,
#
# 1. 將每個class中男性和女性的平均存活率用長形圖可視化
#
# 2. 瞭解性別在各艙等存活率的分布
#
# 3. 繪製堆疊條形圖，x軸代表依據艙等分成男性及女性，y軸代表人數，其中藍色代表死亡人數，橘色代表存活人數。
#
# 4. 瞭解性別在各艙等的存活率的分布 (PS: 跟第一次做 Face.Grid 有何不同??)

# %%
# 導入必要的程式庫
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# 取得資料集
df = sns.load_dataset('titanic')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
# 將每個班級中男性和女性的平均存活率用長形圖可視化
sns.barplot(x = 'sex', y = 'survived', hue = 'class', data = df)
plt.show()

# %% [markdown]
# 在上面的示例中,我們可以看到每個班級中男性和女性的平均存活率。從情節中,我們可以理解,女性存活人數比男性多。在男性和女性中,更多的存活率來自頭等艙。

# %% [markdown]
# 繪製數據子集的小倍數。 FacetGrid 示例,
#
# FacetGrid 類有助於可視化一個變數的分佈,以及使用多個面板在數據集子集中分別顯示多個變數之間的關係。

# %%
# 瞭解在各艙等不同性別的存活率
g = sns.FacetGrid(col = 'pclass', data = df)
g.map(sns.barplot, x = 'sex', y = 'survived', order=['male', 'female'], data = df)
plt.show()

# %%
# 先檢視各艙位存活人數，此時可以使用groupby函數進行分類，
# 其中 survived＝1表示存活，survived＝0表示死亡，將survived加總即為各艙等生存人數。

# df.groupby('pclass').survived.sum()

#加上性別
survived=df.groupby(['pclass','sex']).survived.sum()
print(survived)
# survived.plot(kind='bar')
# Out:
# pclass  sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: survived, dtype: int64

# %%
# 先檢視各艙位存活人數，此時可以使用groupby函數進行分類，
# 其中 survived＝1表示存活，survived＝0表示死亡，將survived加總即為各艙等生存人數。

# df.groupby('pclass').survived.sum()

#加上性別
survived=df.groupby(['pclass','sex']).survived.sum()
print(survived)
survived.plot(kind='bar')
plt.show()
# Out:
# pclass  sex
# 1       female    91
#         male      45
# 2       female    70
#         male      17
# 3       female    72
#         male      47
# Name: survived, dtype: int64

# %%
# 使用pd.crosstab函數繪製交叉表，交叉表可以很直觀的依據艙位等級及性別來查看存活人數及死亡人數。
# 繪製堆疊條形圖，x軸代表依據艙等分成男性及女性，y軸代表人數，其中藍色代表死亡人數，橘色代表存活人數。
survived_counts = pd.crosstab([df.pclass, df.sex],df.survived)
print(survived_counts)
# Out:
# survived         0   1
# pclass sex
# 1      female    3  91
#        male     77  45
# 2      female    6  70
#        male     91  17
# 3      female   72  72
#        male    300  47

# %%
survived_counts.plot(kind='bar',stacked=True)
plt.show()

# %%
# 瞭解不同性別在各艙等的存活率
h = sns.FacetGrid(col = 'sex', data = df)
h.map(sns.barplot, x = 'pclass', y = 'survived', order=[1,2,3], data = df)
plt.show()

# %%
print(''' PS: 跟第一次做 Face.Grid 有何不同??
ANS: 使用的欄位不一樣''')
# Out:
#  PS: 跟第一次做 Face.Grid 有何不同??
# ANS: 使用的欄位不一樣

# %% [markdown]
# 可以嘗試其他的參數對照組合
#
#  0   survived
#  1   pclass
#  2   sex
#  3   age
#  5   parch
#  6   fare
#  7   embarked
#  8   class
#  9   who
#  10  adult_male
#  11  deck
#  12  embark_town
#  13  alive
#  14  alone

# %%
for i in df.columns:
    for j in df.columns:
        if i != j:
            try:
                sns.FacetGrid(col = 'sex', data = df).map(sns.barplot, x = j, y = i, data = df)
            except:
                pass
            print(j, 'to', i)
            plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
# pclass to survived
# sex to survived
# age to survived
# sibsp to survived
# parch to survived
# fare to survived
# embarked to survived
# class to survived
# who to survived
# adult_male to survived
# deck to survived
# embark_town to survived
# alive to survived
# alone to survived
# survived to pclass
# sex to pclass
# age to pclass
# sibsp to pclass
# parch to pclass
# fare to pclass
# embarked to pclass
# class to pclass
# who to pclass
# adult_male to pclass
# deck to pclass
# embark_town to pclass
# alive to pclass
# alone to pclass
# survived to sex
# pclass to sex
# age to sex
# sibsp to sex
# parch to sex
# fare to sex
# embarked to sex
# class to sex
# who to sex
# adult_male to sex
# deck to sex
# embark_town to sex
# alive to sex
# alone to sex
# survived to age
# ...
